# %%
import pyforest

A = {1,2,}
B = {1,2,3}
c = {1,2}
c.issubset(A)
# Out:
# True

# %%
A>=c
# Out:
# True

# %%
import pandas as pd

x = [1, 2, 3, 4, 5]
mean_value = pd.Series(x).mean()
print(mean_value)
# Out:
# 3.0

# %%
import pandas as pd

x = [1, 2, 3, 4, 5]
mean = sum(x)/len (x)
print(mean)
# Out:
# 3.0

# %%
import random
import matplotlib.pyplot as plt

# Simulate rolling a die 1000 times
rolls = [random.randint(1, 6) for _ in range(1000)]

# Count occurrences of each outcome
outcomes = {i: rolls.count(i) / 1000 for i in range(1, 7)}

# Plot the results
plt.bar(outcomes.keys(), outcomes.values(), color='skyblue', edgecolor='black')

# Labels and title
plt.xlabel("Dice Outcome")
plt.ylabel("Probability")
plt.title("Dice Roll Probability Distribution")
plt.xticks(range(1, 7))

plt.show()
